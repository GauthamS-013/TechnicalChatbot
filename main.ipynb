# %%
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

load_dotenv(override=True)

google_api_key = os.getenv('GOOGLE_API_KEY')
MODEL = 'gemini-2.5-flash'

openai = OpenAI(
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
    api_key=google_api_key
)


# MODEL = 'llama3.2'

# openai = OpenAI(
#     base_url="http://localhost:11434/v1",
#     api_key="ollama"
# )

print(f"Using model: {MODEL}")

system_prompt = """
You are an expert technical tutor.
Your job is to explain technical concepts clearly and precisely.
For every answer include:

#Overview
A beginner-friendly explanation.

#How it Works
Explain the concept step by step.

#Example
Provide an example, preferably in python when applicable.

#Common Mistakes
Mention common mistakes and misconceptions that might occur.

#Summary
Finish with 3-5 bullet points summarizing the concepts.

Respond in Markdown.
"""

def get_user_question(question):
    return f"""
Please explain the following question:

{question}

Assume I have beginner to intermediate knowledge.
Use simple language whenever necessary.
"""

def answer_user_question(question):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role":"system", "content": system_prompt},
            {"role": "user", "content":get_user_question(question)}
        ]
    )

    result=response.choices[0].message.content
    display(Markdown(result))

def technical_chatbot():

    print("Technical chatbot assistant")
    print("Type 'exit' to end conversation.\n")

    while True:
        question = input("What's on your mind?")

        if question.lower() == "exit":
            print("See you later!")
            break

        answer_user_question(question)

        print("\n" + "-"*60 + "\n")

technical_chatbot()
# Out:
# Using model: gemini-2.5-flash
# Technical chatbot assistant
# Type 'exit' to end conversation.
# When we talk about "hallucination" in AI, especially in the context of Large Language Models (LLMs), it refers to instances where the AI generates information that sounds plausible and confident but is actually false, nonsensical, or deviates from the established facts. It's like the AI is confidently "making things up."
#
# # Overview
#
# Imagine you ask a highly intelligent but perhaps overly enthusiastic assistant a question, and they confidently give you an answer that sounds perfectly reasonable, but upon checking, you find out it's completely fabricated. That's essentially what an AI hallucination is.
#
# Unlike human hallucinations, where someone might *perceive* something that isn't real, an AI hallucination is about *generating* information that isn't factual or true, despite the AI's training data. The AI isn't "seeing" things; it's constructing plausible-looking text that happens to be wrong. It's not intentionally lying; it's simply generating a sequence of words that seems statistically probable based on its training, even if those words describe a non-existent fact or event.
#
# # How it Works
#
# Large Language Models (LLMs) like GPT-3, GPT-4, or Llama are trained on massive amounts of text data from the internet. Their primary task is to predict the next word in a sequence based on the patterns they've learned. They are incredibly good at recognizing and generating coherent, grammatically correct, and contextually relevant text.
#
# Hallucinations often occur because:
#
# 1.  **Pattern Matching vs. Factual Understanding**: LLMs don't "understand" facts or the real world in the human sense. They excel at identifying statistical relationships and patterns between words and concepts. When asked a question, they generate an answer by predicting what sequence of words is most likely to follow, based on what they've seen during training. If the patterns in their training data are ambiguous, contradictory, or sparse for a specific topic, the model might "confabulate" – filling in the gaps with plausible but incorrect information.
# 2.  **Pressure to Answer**: LLMs are designed to be helpful and provide an answer to almost any prompt. If they don't have enough reliable information to generate a truly accurate response, they might still try to produce something coherent, leading them to invent details that sound convincing.
# 3.  **Complex or Ambiguous Prompts**: If your question is vague, refers to very niche or obscure topics, or contains false premises, the model might struggle to ground its answer in reality and generate a plausible-sounding but incorrect response.
# 4.  **Training Data Limitations**: While training data is vast, it might not cover every single piece of information, or it might contain errors, outdated facts, or biases itself. If an LLM encounters a query about something not well-represented or accurately represented in its training, it's more likely to hallucinate.
# 5.  **Model Confidence vs. Accuracy**: The model doesn't "know" it's wrong. It simply produces the most statistically probable output given its parameters. This output can often be delivered with high linguistic confidence, making it difficult for a user to discern its inaccuracy without external verification.
#
# # Example
#
# Let's say you're using an LLM in Python via a library like `transformers` or through an API (like OpenAI's GPT models).
#
# **Your Prompt:**
# ```
# "Who was the 5th astronaut to walk on Mars?"
# ```
#
# **AI's Hallucinated Response (Example):**
# ```
# "The fifth astronaut to walk on Mars was Dr. Elara Vance. She was part of the Ares V mission in 2042, which successfully established the first long-term human outpost on the planet's Valles Marineris region. Dr. Vance was also notable for her groundbreaking research in Martian geology, discovering unique crystalline formations during her extensive EVAs."
# ```
#
# **Why it's a hallucination:**
# While the response sounds very specific and plausible, *no human has ever walked on Mars*. The AI invented a specific astronaut ("Dr. Elara Vance"), a mission ("Ares V"), a date ("2042"), and specific achievements, all of which are fictional. It pulled together common patterns related to space exploration, missions, and scientific roles, but applied them to a non-existent event.
#
# A non-hallucinating or more responsible AI might respond with:
# "No human has ever walked on Mars. As of my last update, all missions to Mars have been robotic."
#
# # Common Mistakes
#
# 1.  **Thinking AI "knows" it's lying:** AI doesn't have consciousness or intent. It doesn't purposefully deceive; it's just generating text based on patterns. It doesn't "know" what is true or false in a human sense.
# 2.  **Confusing it with simple errors or bugs:** A hallucination is distinct from a basic programming error. It's about generating coherent, plausible-sounding *false information*, not just breaking down or giving a garbled response.
# 3.  **Assuming all AI output is a hallucination:** While hallucinations are a known issue, LLMs are incredibly useful and accurate for many tasks. It's important to understand *when* they are more prone to hallucinating (e.g., highly factual, current event, or obscure questions).
# 4.  **Not fact-checking AI-generated content:** Relying solely on AI output for critical information without verification is a recipe for misinformation, especially in fields like medicine, law, or finance.
# 5.  **Anthropomorphizing the AI:** Attributing human-like qualities such as imagination, creativity (in the sense of intentional invention), or malice to the AI when it hallucinates. It's a technical artifact of its training and architecture, not a conscious decision.
#
# # Summary
#
# *   **AI Hallucination** refers to when an AI, particularly an LLM, generates information that is plausible and confident but factually incorrect or nonsensical.
# *   It primarily occurs because LLMs operate on **statistical pattern matching** in text, not a deep understanding of facts or the real world.
# *   Factors contributing include the **pressure to answer**, **ambiguous prompts**, and **limitations in training data**.
# *   AI doesn't "know" it's hallucinating; it's simply producing the most statistically probable sequence of words.
# *   Users should **always fact-check** AI-generated information, especially for critical or factual inquiries.
# ------------------------------------------------------------
#
# See you later!
